# %%
# change tabula to tabula_middle_padding to test middle padding method
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
from tabula_middle_padding import Tabula 
import pandas as pd
import torch

# %%
data = pd.read_csv("/drive1/zhd/Tabula/Real_Datasets/Insurance_compressed.csv")

# %%
#categorical_columns = ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'native-country', 'income']
model = Tabula(llm='distilgpt2', experiment_dir = "insurance_training", batch_size=32, epochs=400)

# %% [markdown]
# ## In following block, it is important to indicate "conditional_col = data.columns[0]". Otherwise, the generation will use target column as conditional column, which will result in error!

# %%
model.fit(data, conditional_col = data.columns[0])
# Out:
# /drive1/zhd/Tabula/tabula_middle_padding/tabula.py:130: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `TabulaTrainer.__init__`. Use `processing_class` instead.
#   tabula_trainer = TabulaTrainer(self.model, training_args, train_dataset=tabula_ds, tokenizer=self.tokenizer,
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 50256}.
# `loss_type=None` was set in the config but it is unrecognized. Using the default loss: `ForCausalLMLoss`.
#     <div>
#
#       <progress value='79' max='16800' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   79/16800 00:04 < 15:59, 17.43 it/s, Epoch 1.86/400]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model.fit(data, conditional_col = data.columns[0])
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula.py:135, in Tabula.fit(self, data, column_names, conditional_col, resume_from_checkpoint)
#     133 # Start training
#     134 logging.info("Start training...")
# --> 135 tabula_trainer.train(resume_from_checkpoint=resume_from_checkpoint)
#     136 return tabula_trainer
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/transformers/trainer.py:2325, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2323         hf_hub_utils.enable_progress_bars()
#    2324 else:
# -> 2325     return inner_training_loop(
#    2326         args=args,
#    2327         resume_from_checkpoint=resume_from_checkpoint,
#    2328         trial=trial,
#    2329         ignore_keys_for_eval=ignore_keys_for_eval,
#    2330     )
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/transformers/trainer.py:2618, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2616 update_step += 1
#    2617 num_batches = args.gradient_accumulation_steps if update_step != (total_updates - 1) else remainder
# -> 2618 batch_samples, num_items_in_batch = self.get_batch_samples(epoch_iterator, num_batches, args.device)
#    2619 # Store the number of batches for current gradient accumulation
#    2620 # This is used to correctly scale the loss when the last accumulation step has fewer batches
#    2621 self.current_gradient_accumulation_steps = len(batch_samples)
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/transformers/trainer.py:5654, in Trainer.get_batch_samples(self, epoch_iterator, num_batches, device)
#    5652 for _ in range(num_batches):
#    5653     try:
# -> 5654         batch_samples.append(next(epoch_iterator))
#    5655     except StopIteration:
#    5656         break
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/torch/utils/data/dataloader.py:732, in _BaseDataLoaderIter.__next__(self)
#     729 if self._sampler_iter is None:
#     730     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     731     self._reset()  # type: ignore[call-arg]
# --> 732 data = self._next_data()
#     733 self._num_yielded += 1
#     734 if (
#     735     self._dataset_kind == _DatasetKind.Iterable
#     736     and self._IterableDataset_len_called is not None
#     737     and self._num_yielded > self._IterableDataset_len_called
#     738 ):
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/torch/utils/data/dataloader.py:788, in _SingleProcessDataLoaderIter._next_data(self)
#     786 def _next_data(self):
#     787     index = self._next_index()  # may raise StopIteration
# --> 788     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     789     if self._pin_memory:
#     790         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:50, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      48 if self.auto_collation:
#      49     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 50         data = self.dataset.__getitems__(possibly_batched_index)
#      51     else:
#      52         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula_dataset.py:53, in TabulaDataset.__getitems__(self, keys)
#      51 def __getitems__(self, keys: tp.Union[int, slice, str, list]):
#      52     if isinstance(keys, list):
# ---> 53         return [self._getitem(key) for key in keys]
#      54     else:
#      55         return self._getitem(keys)
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula_dataset.py:53, in <listcomp>(.0)
#      51 def __getitems__(self, keys: tp.Union[int, slice, str, list]):
#      52     if isinstance(keys, list):
# ---> 53         return [self._getitem(key) for key in keys]
#      54     else:
#      55         return self._getitem(keys)
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula_dataset.py:33, in TabulaDataset._getitem(self, key, decoded, **kwargs)
#      28 """ Get Item from Tabular Data
#      29
#      30 Get one instance of the tabular data, permuted, converted to text and tokenized.
#      31 """
#      32 # If int, what else?
# ---> 33 row = self._data.fast_slice(key, 1)
#      35 idx_range = list(range(row.num_columns))
#      36 # random.shuffle(shuffle_idx)
#
# File ~/anaconda3/envs/tabula/lib/python3.10/site-packages/datasets/table.py:150, in IndexedTableMixin.fast_slice(self, offset, length)
#     148     batches[-1] = batches[-1].slice(0, offset + length - self._offsets[j])
#     149     batches[0] = batches[0].slice(offset - self._offsets[i])
# --> 150 return pa.Table.from_batches(batches, schema=self._schema)
#
# KeyboardInterrupt:

# %%
import torch
torch.save(model.model.state_dict(), "insurance_training/model_400epoch.pt")

# %%
synthetic_data = model.sample(n_samples=1338)
synthetic_data.to_csv("insurance_400epoch.csv", index=False)
# Out:
#   0%|          | 0/1338 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 synthetic_data = model.sample(n_samples=1338)
#       2 synthetic_data.to_csv("insurance_50epoch.csv", index=False)
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula.py:174, in Tabula.sample(self, n_samples, start_col, start_col_dist, temperature, k, max_length, device)
#     172 already_generated = 0
#     173 while n_samples > df_gen.shape[0]:
# --> 174     start_tokens = tabula_start.get_start_tokens(k)
#     175     start_tokens = torch.tensor(start_tokens).to(device)
#     177     # Generate tokens
#
# File /drive1/zhd/Tabula/tabula_middle_padding/tabula_start.py:154, in RandomStart.get_start_tokens(self, n_samples)
#     153 def get_start_tokens(self, n_samples):
# --> 154     start_words = random.choices(self.all_columns, k=n_samples)
#     155     start_text = [s + " " for s in start_words]
#     156     start_tokens = _pad_tokens(self.tokenizer(start_text)["input_ids"])
#
# File ~/anaconda3/envs/tabula/lib/python3.10/random.py:514, in Random.choices(self, population, weights, cum_weights, k)
#     507 """Return a k sized list of population elements chosen with replacement.
#     508
#     509 If the relative weights or cumulative weights are not specified,
#     510 the selections are made with equal probability.
#     511
#     512 """
#     513 random = self.random
# --> 514 n = len(population)
#     515 if cum_weights is None:
#     516     if weights is None:
#
# TypeError: object of type 'NoneType' has no len()
